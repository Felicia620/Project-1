# %%
#Dependencies
import pandas as pd
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plotter

file_2015 = "Resources/2015CensusData.csv"
file_2016 = "Resources/NewJerseyCensus2016.csv"
file_2017 = "Resources/2017CensusData.csv"
file_2018 = "Resources/2018CensusData.csv"
file_2019 = "Resources/2019CensusData.csv"

# %%
file_2015_df = pd.read_csv(file_2015)
file_2016_df = pd.read_csv(file_2016)
file_2017_df = pd.read_csv(file_2017)
file_2018_df = pd.read_csv(file_2018)
file_2019_df = pd.read_csv(file_2019)

# %%
print(file_2016_df)
# Out:
#      Unnamed: 0         Name  Household Income  Asian American  \
# 0         15064  ZCTA5 07504           50203.0             8.0
# 1         15065  ZCTA5 07505           28426.0            61.0
# 2         15066  ZCTA5 07506           89472.0           216.0
# 3         15067  ZCTA5 07508           75578.0           992.0
# 4         15068  ZCTA5 07512           96573.0           695.0
# ..          ...          ...               ...             ...
# 590       29950  ZCTA5 07481          143750.0           857.0
# 591       29951  ZCTA5 07495      -666666666.0             0.0
# 592       29952  ZCTA5 07501           25379.0           676.0
# 593       29953  ZCTA5 07502           54840.0          2562.0
# 594       29954  ZCTA5 07503           34867.0           606.0
#
#      Black American  Hispanic American  White American    Other  state  \
# 0            6429.0             5587.0          2670.0   1946.0     34
# ...

# %%
file_2016_df_new = file_2016_df.rename(columns={"Household Income": "Household Income",
                                             "Asian American": "Asian Amer.",
                                              "Black American": "Black Amer.",
                                               "Hispanic American":"Hispanic Amer.",
                                               "White American":"White Amer.",
                                               "Other":"Other",
                                               "state": "state",
                                               "Zip Code": "Zipcode"})

print(file_2016_df_new)
# Out:
#      Unnamed: 0         Name  Household Income  Asian Amer.  Black Amer.  \
# 0         15064  ZCTA5 07504           50203.0          8.0       6429.0
# 1         15065  ZCTA5 07505           28426.0         61.0       1039.0
# 2         15066  ZCTA5 07506           89472.0        216.0        299.0
# 3         15067  ZCTA5 07508           75578.0        992.0       1863.0
# 4         15068  ZCTA5 07512           96573.0        695.0        422.0
# ..          ...          ...               ...          ...          ...
# 590       29950  ZCTA5 07481          143750.0        857.0         66.0
# 591       29951  ZCTA5 07495      -666666666.0          0.0          0.0
# 592       29952  ZCTA5 07501           25379.0        676.0       9226.0
# 593       29953  ZCTA5 07502           54840.0       2562.0       3603.0
# 594       29954  ZCTA5 07503           34867.0        606.0       1055.0
#
#      Hispanic Amer.  White Amer.    Other  state  Zipcode
# ...

# %%
#eg. merge_df = pd.merge(info_df, items_df, on="customer_id")

merge_df_1 = pd.merge(file_2015_df, file_2016_df_new, on = "Zipcode")
print(merge_df_1)
# Out:
#      Unnamed: 0_x       Name_x  Household Income_x  Asian Amer._x  \
# 0            9602  ZCTA5 07001             68036.0         3925.0
# 1            9603  ZCTA5 07002             54413.0         5822.0
# 2            9604  ZCTA5 07003             72791.0         4325.0
# 3            9605  ZCTA5 07004            106691.0          128.0
# 4            9606  ZCTA5 07005            100582.0         1085.0
# ..            ...          ...                 ...            ...
# 590         32652  ZCTA5 08011                 NaN            0.0
# 591         32873  ZCTA5 07977                 NaN           12.0
# 592         32926  ZCTA5 08038                 NaN            0.0
# 593         33081  ZCTA5 08073                 NaN            0.0
# 594         33098  ZCTA5 07846                 NaN            0.0
#
#      Black Amer._x  Hispanic Amer._x  White Amer._x  Other_x  state_x  \
# 0           4449.0            2925.0         9123.0    423.0       34
# ...

# %%
merge_df_1["Total_1_Household Income"] = merge_df_1["Household Income_x"] + merge_df_1["Household Income_y"]
merge_df_1["Total_1_Asian Amer."] = merge_df_1["Asian Amer._x"] + merge_df_1["Asian Amer._y"]
merge_df_1["Total_1_Black Amer."] = merge_df_1["Black Amer._x"] + merge_df_1["Black Amer._y"]
merge_df_1["Total_1_Hispanic Amer."] = merge_df_1["Hispanic Amer._x"] + merge_df_1["Hispanic Amer._y"]
merge_df_1["Total_1_White Amer."] = merge_df_1["White Amer._x"] + merge_df_1["White Amer._y"]
merge_df_1["Total_1_Other"] = merge_df_1["Other_x"] + merge_df_1["Other_y"]
merge_df_1["Total_1_Zipcode"] = merge_df_1["Zipcode"]

print(merge_df_1.head())
# Out:
#    Unnamed: 0_x       Name_x  Household Income_x  Asian Amer._x  \
# 0          9602  ZCTA5 07001             68036.0         3925.0
# 1          9603  ZCTA5 07002             54413.0         5822.0
# 2          9604  ZCTA5 07003             72791.0         4325.0
# 3          9605  ZCTA5 07004            106691.0          128.0
# 4          9606  ZCTA5 07005            100582.0         1085.0
#
#    Black Amer._x  Hispanic Amer._x  White Amer._x  Other_x  state_x  Zipcode  \
# 0         4449.0            2925.0         9123.0    423.0       34     7001
# 1         7095.0           15375.0        46266.0   4194.0       34     7002
# 2         8519.0           12854.0        29693.0   3624.0       34     7003
# 3            0.0             282.0         7376.0     16.0       34     7004
# 4          516.0            1309.0        13180.0    267.0       34     7005
#
#    ...  White Amer._y Other_y  state_y  Total_1_Household Income  \
# ...

# %%
updated_merge_df_1 = merge_df_1.drop(["Unnamed: 0_x", "Name_y", "Name_x","Household Income_x","Household Income_y","Asian Amer._x","Asian Amer._y","Black Amer._x", "Black Amer._y","Hispanic Amer._x","Hispanic Amer._y","White Amer._x","White Amer._y","Other_x", "Other_y", "state_x", "Total_1_Zipcode"], axis=1)
print(updated_merge_df_1.head())
# Out:
#    Zipcode  Unnamed: 0_y  state_y  Total_1_Household Income  \
# 0     7001         29809       34                  132857.0
# 1     7002         29810       34                  109275.0
# 2     7003         29811       34                  145672.0
# 3     7004         29812       34                  207004.0
# 4     7005         29813       34                  205420.0
#
#    Total_1_Asian Amer.  Total_1_Black Amer.  Total_1_Hispanic Amer.  \
# 0               7505.0               9122.0                  6006.0
# 1              12321.0              14061.0                 32464.0
# 2               8697.0              17194.0                 26202.0
# 3                378.0                  0.0                   595.0
# 4               2314.0                900.0                  2782.0
#
#    Total_1_White Amer.  Total_1_Other
# 0              18049.0         1066.0
# 1              90616.0         9644.0
# 2              59818.0         7065.0
# ...

# %%
#merging df_1 with 2017

merge_df_2 = pd.merge(updated_merge_df_1,file_2017_df, on="Zipcode")
print(merge_df_2.head())
# Out:
#    Zipcode  Unnamed: 0_y  state_y  Total_1_Household Income  \
# 0     7001         29809       34                  132857.0
# 1     7002         29810       34                  109275.0
# 2     7003         29811       34                  145672.0
# 3     7004         29812       34                  207004.0
# 4     7005         29813       34                  205420.0
#
#    Total_1_Asian Amer.  Total_1_Black Amer.  Total_1_Hispanic Amer.  \
# 0               7505.0               9122.0                  6006.0
# 1              12321.0              14061.0                 32464.0
# 2               8697.0              17194.0                 26202.0
# 3                378.0                  0.0                   595.0
# 4               2314.0                900.0                  2782.0
#
#    Total_1_White Amer.  Total_1_Other  Unnamed: 0         Name  \
# 0              18049.0         1066.0        1963  ZCTA5 07001
# 1              90616.0         9644.0        1964  ZCTA5 07002
# ...

# %%
merge_df_2["Total_2_Household Income"] = merge_df_2["Total_1_Household Income"] + merge_df_2["Household Income"]
merge_df_2["Total_2_Asian Amer."] = merge_df_2["Total_1_Asian Amer."] + merge_df_2["Asian Amer."]
merge_df_2["Total_2_Black Amer."] = merge_df_2["Total_1_Black Amer."] + merge_df_2["Black Amer."]
merge_df_2["Total_2_Hispanic Amer."] = merge_df_2["Total_1_Hispanic Amer."] + merge_df_2["Hispanic Amer."]
merge_df_2["Total_2_White Amer."] = merge_df_2["Total_1_White Amer."] + merge_df_2["White Amer."]
merge_df_2["Total_2_Other"] = merge_df_2["Total_1_Other"] + merge_df_2["Other"]
merge_df_2["Total_2_Zipcode"] = merge_df_2["Zipcode"]

print(merge_df_2.head())
# Out:
#    Zipcode  Unnamed: 0_y  state_y  Total_1_Household Income  \
# 0     7001         29809       34                  132857.0
# 1     7002         29810       34                  109275.0
# 2     7003         29811       34                  145672.0
# 3     7004         29812       34                  207004.0
# 4     7005         29813       34                  205420.0
#
#    Total_1_Asian Amer.  Total_1_Black Amer.  Total_1_Hispanic Amer.  \
# 0               7505.0               9122.0                  6006.0
# 1              12321.0              14061.0                 32464.0
# 2               8697.0              17194.0                 26202.0
# 3                378.0                  0.0                   595.0
# 4               2314.0                900.0                  2782.0
#
#    Total_1_White Amer.  Total_1_Other  Unnamed: 0  ... White Amer.   Other  \
# 0              18049.0         1066.0        1963  ...      8683.0   846.0
# ...

# %%
##Updated_New_Jersey_Census_2018 = New_Jersey_Census_2018.drop(["B05002_001E"], axis=1)

updated_merge_df_2 = merge_df_2.drop(["Household Income", "Asian Amer.","Black Amer.", "Hispanic Amer.","Unnamed: 0_y", "state_y","Total_1_Household Income","Total_1_Asian Amer.","Total_1_Black Amer.","Total_1_Hispanic Amer.","Total_1_White Amer.", "Total_1_Other","White Amer.", "Other", "Total_2_Zipcode"], axis=1)
print(updated_merge_df_2.head())
# Out:
#    Zipcode  Unnamed: 0         Name  state  Total_2_Household Income  \
# 0     7001        1963  ZCTA5 07001     34                  201283.0
# 1     7002        1964  ZCTA5 07002     34                  165976.0
# 2     7003        1965  ZCTA5 07003     34                  220633.0
# 3     7004        1966  ZCTA5 07004     34                  314421.0
# 4     7005        1967  ZCTA5 07005     34                  315308.0
#
#    Total_2_Asian Amer.  Total_2_Black Amer.  Total_2_Hispanic Amer.  \
# 0              11189.0              13772.0                  9687.0
# 1              18303.0              21476.0                 52215.0
# 2              13309.0              26336.0                 40003.0
# 3                637.0                  0.0                  1064.0
# 4               3628.0               1199.0                  4294.0
#
#    Total_2_White Amer.  Total_2_Other
# 0              26732.0         1912.0
# 1             134448.0        16161.0
# ...

# %%
#merging df_2 with 2018

merge_df_3 = pd.merge(updated_merge_df_2,file_2018_df, on = "Zipcode")
print(merge_df_3.head())
# Out:
#    Zipcode  Unnamed: 0_x       Name_x  state_x  Total_2_Household Income  \
# 0     7001          1963  ZCTA5 07001       34                  201283.0
# 1     7002          1964  ZCTA5 07002       34                  165976.0
# 2     7003          1965  ZCTA5 07003       34                  220633.0
# 3     7004          1966  ZCTA5 07004       34                  314421.0
# 4     7005          1967  ZCTA5 07005       34                  315308.0
#
#    Total_2_Asian Amer.  Total_2_Black Amer.  Total_2_Hispanic Amer.  \
# 0              11189.0              13772.0                  9687.0
# 1              18303.0              21476.0                 52215.0
# 2              13309.0              26336.0                 40003.0
# 3                637.0                  0.0                  1064.0
# 4               3628.0               1199.0                  4294.0
#
#    Total_2_White Amer.  Total_2_Other  Unnamed: 0_y       Name_y  \
# ...

# %%
merge_df_3["Total_3_Household Income"] = merge_df_3["Total_2_Household Income"] + merge_df_3["Household Income"]
merge_df_3["Total_3_Asian Amer."] = merge_df_3["Total_2_Asian Amer."] + merge_df_3["Asian Amer."]
merge_df_3["Total_3_Black Amer."] = merge_df_3["Total_2_Black Amer."] + merge_df_3["Black Amer."]
merge_df_3["Total_3_Hispanic Amer."] = merge_df_3["Total_2_Hispanic Amer."] + merge_df_3["Hispanic Amer."]
merge_df_3["Total_3_White Amer."] = merge_df_3["Total_2_White Amer."] + merge_df_3["White Amer."]
merge_df_3["Total_3_Other"] = merge_df_3["Total_2_Other"] + merge_df_3["Other"]
merge_df_3["Total_3_Zipcode"] = merge_df_3["Zipcode"]

print(merge_df_3.head())
# Out:
#    Zipcode  Unnamed: 0_x       Name_x  state_x  Total_2_Household Income  \
# 0     7001          1963  ZCTA5 07001       34                  201283.0
# 1     7002          1964  ZCTA5 07002       34                  165976.0
# 2     7003          1965  ZCTA5 07003       34                  220633.0
# 3     7004          1966  ZCTA5 07004       34                  314421.0
# 4     7005          1967  ZCTA5 07005       34                  315308.0
#
#    Total_2_Asian Amer.  Total_2_Black Amer.  Total_2_Hispanic Amer.  \
# 0              11189.0              13772.0                  9687.0
# 1              18303.0              21476.0                 52215.0
# 2              13309.0              26336.0                 40003.0
# 3                637.0                  0.0                  1064.0
# 4               3628.0               1199.0                  4294.0
#
#    Total_2_White Amer.  Total_2_Other  ...  White Amer.   Other  state_y  \
# ...

# %%
updated_merge_df_3 = merge_df_3.drop(["Unnamed: 0_x","Name_x","state_x", "Unnamed: 0_y", "Name_y", "Household Income", "Asian Amer.", "Black Amer.", "Hispanic Amer.", "White Amer.", "Other", "Total_2_Household Income","Total_2_Asian Amer.","Total_2_Black Amer.","Total_2_Hispanic Amer.","Total_2_White Amer.", "Total_2_Other", "Total_3_Zipcode"], axis=1)
print(updated_merge_df_3.head())
# Out:
#    Zipcode  state_y  Total_3_Household Income  Total_3_Asian Amer.  \
# 0     7001       34                  273226.0              14884.0
# 1     7002       34                  225900.0              24738.0
# 2     7003       34                  297120.0              17582.0
# 3     7004       34                  432171.0                950.0
# 4     7005       34                  426688.0               5096.0
#
#    Total_3_Black Amer.  Total_3_Hispanic Amer.  Total_3_White Amer.  \
# 0              18134.0                 13401.0              35703.0
# 1              28986.0                 72749.0             175816.0
# 2              36080.0                 53972.0             120509.0
# 3                  0.0                  1658.0              28699.0
# 4               1680.0                  5816.0              52021.0
#
#    Total_3_Other
# 0         2733.0
# 1        23486.0
# 2        13532.0
# 3           72.0
# 4         1076.0

# %%
#merging df_3 with 2019

merge_df_4 = pd.merge(updated_merge_df_3,file_2019_df, on = "Zipcode")
print(merge_df_4.head())
# Out:
#    Zipcode  state_y  Total_3_Household Income  Total_3_Asian Amer.  \
# 0     7001       34                  273226.0              14884.0
# 1     7002       34                  225900.0              24738.0
# 2     7003       34                  297120.0              17582.0
# 3     7004       34                  432171.0                950.0
# 4     7005       34                  426688.0               5096.0
#
#    Total_3_Black Amer.  Total_3_Hispanic Amer.  Total_3_White Amer.  \
# 0              18134.0                 13401.0              35703.0
# 1              28986.0                 72749.0             175816.0
# 2              36080.0                 53972.0             120509.0
# 3                  0.0                  1658.0              28699.0
# 4               1680.0                  5816.0              52021.0
#
#    Total_3_Other  Unnamed: 0         Name  Household Income  Asian Amer.  \
# 0         2733.0        1963  ZCTA5 07001           69849.0       3542.0
# ...

# %%
merge_df_4["Total_4_Household Income"] = merge_df_4["Total_3_Household Income"] + merge_df_4["Household Income"]
merge_df_4["Total_4_Asian Amer."] = merge_df_4["Total_3_Asian Amer."] + merge_df_4["Asian Amer."]
merge_df_4["Total_4_Black Amer."] = merge_df_4["Total_3_Black Amer."] + merge_df_4["Black Amer."]
merge_df_4["Total_4_Hispanic Amer."] = merge_df_4["Total_3_Hispanic Amer."] + merge_df_4["Hispanic Amer."]
merge_df_4["Total_4_White Amer."] = merge_df_4["Total_3_White Amer."] + merge_df_4["White Amer."]
merge_df_4["Total_4_Other"] = merge_df_4["Total_3_Other"] + merge_df_4["Other"]
merge_df_4["Total_4_Zipcode"] = merge_df_4["Zipcode"]

print(merge_df_4.head())
# Out:
#    Zipcode  state_y  Total_3_Household Income  Total_3_Asian Amer.  \
# 0     7001       34                  273226.0              14884.0
# 1     7002       34                  225900.0              24738.0
# 2     7003       34                  297120.0              17582.0
# 3     7004       34                  432171.0                950.0
# 4     7005       34                  426688.0               5096.0
#
#    Total_3_Black Amer.  Total_3_Hispanic Amer.  Total_3_White Amer.  \
# 0              18134.0                 13401.0              35703.0
# 1              28986.0                 72749.0             175816.0
# 2              36080.0                 53972.0             120509.0
# 3                  0.0                  1658.0              28699.0
# 4               1680.0                  5816.0              52021.0
#
#    Total_3_Other  Unnamed: 0         Name  ...  White Amer.   Other  state  \
# ...

# %%
##Final DataFrame of Total Information

updated_merge_df_4 = merge_df_4.drop(["Unnamed: 0", "Name","Household Income", "Asian Amer.", "Black Amer.", "Hispanic Amer.", "White Amer.", "Other", "state_y","Total_3_Household Income","Total_3_Asian Amer.","Total_3_Black Amer.","Total_3_Hispanic Amer.","Total_3_White Amer.", "Total_3_Other", "Total_4_Zipcode"], axis=1)
print(updated_merge_df_4.head())  
print(len(updated_merge_df_4))
# Out:
#    Zipcode  state  Total_4_Household Income  Total_4_Asian Amer.  \
# 0     7001     34                  343075.0              18426.0
# 1     7002     34                  289847.0              31204.0
# 2     7003     34                  375154.0              21905.0
# 3     7004     34                  554234.0               1221.0
# 4     7005     34                  538634.0               6511.0
#
#    Total_4_Black Amer.  Total_4_Hispanic Amer.  Total_4_White Amer.  \
# 0              22192.0                 17039.0              44953.0
# 1              35874.0                 94537.0             216586.0
# 2              46003.0                 68466.0             150661.0
# 3                  0.0                  2475.0              35704.0
# 4               2160.0                  7265.0              64701.0
#
#    Total_4_Other
# 0         3357.0
# 1        31253.0
# 2        16794.0
# 3           72.0
# 4         1204.0
# 595

# %%
Total_Asian_Amer = updated_merge_df_4["Total_4_Asian Amer."].sum()
print(Total_Asian_Amer)
# Out:
# 4140873.0

# %%
Total_Black_Amer = updated_merge_df_4["Total_4_Black Amer."].sum()
Total_Hispanic_Amer = updated_merge_df_4["Total_4_Hispanic Amer."].sum()
Total_White_Amer = updated_merge_df_4["Total_4_White Amer."].sum()
Total_Other_Amer = updated_merge_df_4["Total_4_Other"].sum()

print(Total_Black_Amer)
print(Total_Hispanic_Amer)
print(Total_White_Amer)
print(Total_Other_Amer)
# Out:
# 6008523.0
# 8735115.0
# 30294945.0
# 2834325.0

# %%
## Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

Race = ["Other", "Asian Amer.", "Black Amer.", "Hispanic Amer.", "White Amer."]
points = ["$2,834,325.0", "$4,140,873.0", "$6,008,523.0", "$8,735,115.0", "$30,294,945.0"]

x_axis = np.arange(0,len(Race))

plt.bar(x_axis, points, color="b", align="center")
plt.title("Total Income Per Race")
plt.ylabel("Total Income")
plt.xlabel("Ethnicity")
tick_location = [value for value in x_axis]
plt.xticks(tick_location,["Other", "Asian", "Black", "Hispanic", "White"])
plt.show
#plt.ylim((2670000,30294950)
plt.tight_layout()
plt.savefig("Resources/TotalIncomeperrace.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2016 Pie Chart Asian American 

Asian_2016 = ["2016 Year", "Total Asian"]
Income = [819208, 4140873]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Asian_2016, colors=colors, autopct="%1.1f%%")
plt.title("2016 vs Total")
plt.xlabel("2016")
plt.ylabel("Asian American")
plt.savefig("Resources/Asian2016.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2017 Pie Chart Asian American 

Asian_2017 = ["2017 Year", "Total Asian"]
Income = [844105, 4140873]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Asian_2017, colors=colors, autopct="%1.1f%%")
plt.title("2017 vs Total")
plt.xlabel("2017")
plt.savefig("Resources/Asian2017.png")
plt.ylabel("Asian American")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2018 Pie Chart Asian American 

Asian_2018 = ["2018 Year", "Total Asian"]
Income = [832403, 4140873]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Asian_2018, colors=colors, autopct="%1.1f%%")
plt.title("2018 vs Total")
plt.xlabel("2018")
plt.ylabel("Asian American")
plt.savefig("Resources/Asian2018.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2019 Pie Chart Asian American 

Asian_2019 = ["2019 Year", "Total Asian"]
Income = [840168, 4140873]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Asian_2019, colors=colors, autopct="%1.1f%%")
plt.title("2019 vs Total")
plt.xlabel("2019")
plt.ylabel("Asian American")
plt.savefig("Resources/Asian2019.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2015 Need The Numbers

# %%
#2016 Pie Chart Black American 

Black_2016 = ["2016 Year", "Total Black"]
Income = [1207221, 6008523]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Black_2016, colors=colors, autopct="%1.1f%%")
plt.title("2016 vs Total")
plt.xlabel("2016")
plt.ylabel("Black American")
plt.savefig("Resources/Black2016.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2017 Pie Chart Black American 

Black_2017 = ["2017 Year", "Total Black"]
Income = [1207356, 6008523]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Black_2017, colors=colors, autopct="%1.1f%%")
plt.title("2017 vs Total")
plt.xlabel("2017")
plt.ylabel("Black American")
plt.savefig("Resources/Black2017.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2018 Pie Chart Black American 

Black_2018 = ["2018 Year", "Total Black"]
Income = [1196764, 6008523]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Black_2018, colors=colors, autopct="%1.1f%%")
plt.title("2018 vs Total")
plt.xlabel("2018")
plt.ylabel("Black American")
plt.savefig("Resources/Black2018.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2019 Pie Chart Black American 

Black_2019 = ["2019 Year", "Total Black"]
Income = [1194882, 6008523]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Black_2019, colors=colors, autopct="%1.1f%%")
plt.title("2019 vs Total")
plt.xlabel("2019")
plt.ylabel("Black American")
plt.savefig("Resources/Black2019.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2015 Pie Chart Hispanic American Needs The Numbers

# %%
#2016 Pie Chart Hispanic American 

Hispanic_2016 = ["2016 Year", "Total Hispanic"]
Income = [1719831, 8735115]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Hispanic_2016, colors=colors, autopct="%1.1f%%")
plt.title("2016 vs Total")
plt.xlabel("2016")
plt.ylabel("Hispanic American")
plt.savefig("Resources/Hispanic2016.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2017 Pie Chart Hispanic American - Need to Double Check this

Hispanic_2017 = ["2017 Year", "Total Hispanic"]
Income = [1764520, 8735115]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Hispanic_2017, colors=colors, autopct="%1.1f%%")
plt.title("2017 vs Total")
plt.xlabel("2017")
plt.ylabel("Hispanic American")
plt.savefig("Resources/Hispanic2017.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2018 Pie Chart Hispanic American 

Hispanic_2018 = ["2018 Year", "Total Hispanic"]
Income = [1768020, 8735115]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Hispanic_2018, colors=colors, autopct="%1.1f%%")
plt.title("2018 vs Total")
plt.xlabel("2018")
plt.ylabel("Hispanic American")
plt.savefig("Resources/Hispanic2018.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2019 Pie Chart Hispanic American 

Hispanic_2019 = ["2019 Year", "Total Hispanic"]
Income = [1794736, 8735115]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Hispanic_2019, colors=colors, autopct="%1.1f%%")
plt.title("2019 vs Total")
plt.xlabel("2019")
plt.ylabel("Hispanic American")
plt.savefig("Resources/Hispanic2019.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2015 Need the Number for This

# %%
#2016 Pie Chart White American 

White_2016 = ["2016 Year", "Total White"]
Income = [6075710, 30294945]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=White_2016, colors=colors, autopct="%1.1f%%")
plt.title("2016 vs Total")
plt.xlabel("2016")
plt.ylabel("White American")
plt.savefig("Resources/White2016.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2017 Pie Chart White American 

White_2017 = ["2017 Year", "Total White"]
Income = [6085474, 30294945]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=White_2017, colors=colors, autopct="%1.1f%%")
plt.title("2017 vs Total")
plt.xlabel("2017")
plt.ylabel("White American")
plt.savefig("Resources/White2017.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2018 Pie Chart White American 

White_2018 = ["2018 Year", "Total White"]
Income = [6031747, 30294945]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=White_2018, colors=colors, autopct="%1.1f%%")
plt.title("2018 vs Total")
plt.xlabel("2018")
plt.ylabel("White American")
plt.savefig("Resources/White2018.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2019 Pie Chart White American 

White_2019 = ["2019 Year", "Total White"]
Income = [6018074, 30294945]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=White_2019, colors=colors, autopct="%1.1f%%")
plt.title("2019 vs Total")
plt.xlabel("2019")
plt.ylabel("White American")
plt.savefig("Resources/White2019.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2015 Pie Chart Other - Needs the data for this

# %%
#2016 Pie Chart Other American 

Other_2016 = ["2016 Year", "Total Other"]
Income = [566323, 2834325]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Other_2016, colors=colors, autopct="%1.1f%%")
plt.title("2016 vs Total")
plt.xlabel("2016")
plt.ylabel("Other American")
plt.savefig("Resources/Other2016.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2017 Pie Chart Other American - Need The Data For This

# %%
#2018 Pie Chart Other American 

Other_2018 = ["2018 Year", "Total Other"]
Income = [567976, 2834325]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Other_2018, colors=colors, autopct="%1.1f%%")
plt.title("2018 vs Total")
plt.xlabel("2018")
plt.ylabel("Other American")
plt.savefig("Resources/Other2018.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Stacked BAR Chart or plain bar graphs .. tells a great story 
#Sample code only has some of the data as i didnt have all totals
# i will need to include the additional numbers to show all the years
# this daata only shows a 2 year comparison
plotdata = pd.DataFrame({
"Income_2015":[804.989, 1202.300, 1688.008, 6083.940, 568.215],
"Income_2016":[819.208, 1207.221, 1719.831, 6075.710, 566.323],
"Income_2017":[844.105, 1207.356, 1764.520, 6085.474, 573.146],
"Income_2018":[832.403, 1196.764, 1768.020, 6031.747, 567.976], 
"Income_2019":[840.168, 1194.882, 1794.736, 6018.074, 558.665], 
},
index=["Asian", "Black", "Hispanic", "White","Other"]
)
width =0.5

# plt.bar(np.arange(len(data1)), data1, width=width)
# plt.bar(np.arange(len(data2))+ width, data2, width=width)

# plt.bar(np.arange(len(data1)), data1, width=width)
# plt.bar(np.arange(len(data2))+ width, data2, width=width)


plotdata.plot(kind="bar")
plt.title("Income per race between 2014 and 2019")
plt.xlabel("Ethnicity")
plt.xticks(rotation='horizontal')
plt.ylabel("Income Per Year in (x $1,000)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Income Per Year in (x $1,000)')

# %%
# Combination of Ethnicity/Income/ for 2015 - this shows that in 2015, Whites and Hispanics had t
ethnicitylabels = ["Asian", "Black", "Hispanic", "White","Other"]

# The values of each section of the pie chart
sizes = [804989, 1202300, 1688008, 6083940, 568215]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","brown"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,

        labels=ethnicitylabels,

        autopct='%1.2f',

        startangle=90)


# Aspect ratio - equal means pie is a circle
plt.title("Ethnicity Income rate for 2015")
plt.savefig("Resources/Allracesincome2015.png")

axesObject.axis('equal')

plotter.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="640">

# %%
# Combination of Ethnicity/Income/ for 2016 - this shows that in 2016, Whites and Hispanics had t
ethnicitylabels = ["Asian", "Black", "Hispanic", "White","Other"]

# The values of each section of the pie chart
sizes = [819208, 1207221, 1719831, 6075710, 566323]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","brown"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,

        labels=ethnicitylabels,

        autopct='%1.2f',

        startangle=90)


# Aspect ratio - equal means pie is a circle
plt.title("Ethnicity Income rate for 2016")
plt.savefig("Resources/Other2016.png")



axesObject.axis('equal')

plotter.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="640">

# %%
# Combination of Ethnicity/Income/ for 2017 - (need to check with Ryan)
ethnicitylabels = ["Asian", "Black", "Hispanic", "White","Other"]

# The values of each section of the pie chart
sizes = [844105, 1207356, 1764520, 6085474, 573146]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","brown"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,

        labels=ethnicitylabels,

        autopct='%1.2f',

        startangle=90)


# Aspect ratio - equal means pie is a circle
plt.title("Ethnicity Income rate for 2017")
plt.savefig("Resources/Other2017.png")



axesObject.axis('equal')

plotter.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="640">

# %%
# Combination of Ethnicity/Income/ for 2018 - (Check w/Donett)
ethnicitylabels = ["Asian", "Black", "Hispanic", "White","Other"]

# The values of each section of the pie chart - check with Donett
sizes = [832403, 1196764, 1768020, 6031747, 567976]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","brown"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,

        labels=ethnicitylabels,

        autopct='%1.2f',

        startangle=90)


# Aspect ratio - equal means pie is a circle
plt.title("Ethnicity Income rate for 2018")
plt.savefig("Resources/Other2018.png")



axesObject.axis('equal')

plotter.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="640">

# %%
#combination of Ethnicity/Income/ for 2019  - need to check with Carlyse

ethnicitylabels = ["Asian", "Black", "Hispanic", "White","Other"]

# The values of each section of the pie chart - check with Carlyse
sizes = [840168, 1194882, 1794736, 6018074, 558665]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","brown"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,

        labels=ethnicitylabels,

        autopct='%1.2f',

        startangle=90)


# Aspect ratio - equal means pie is a circle
plt.title("Ethnicity Income rate for 2019")
plt.savefig("Resources/Other2019.png")



axesObject.axis('equal')

plotter.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="640">

# %%
#2019 Pie Chart Other American 

Other_2019 = ["2019 Year", "Total Other"]
Income = [558665, 2834325]

colors = ["red", "blue"]
explode = (0,0)

figure, axis = plt.subplots(1,1)
plt.pie(Income, explode=explode, labels=Other_2019, colors=colors, autopct="%1.1f%%")
plt.title("2019 vs Total")
plt.xlabel("2019")
plt.ylabel("Other American")
plt.savefig("Resources/Other2019.png")
plt.show()
plt.tight_layout()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
# <img src="data:image/png;base64,..." width="640">

# %%
total_Income = [2834325.0, 4140873.0, 6008523.0, 8735115.0, 30294945.0]

red_square = dict(markerfacecolor="r", marker="s")
fig1, axl = plt.subplots()
axl.set_title("Final Totals")
axl.boxplot(total_Income, flierprops=red_square)
plt.savefig("Resources/BoxPlotTotals.png")
plt.show()
# Out:
# /Users/petagaye/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# <img src="data:image/png;base64,..." width="640">

# %%
#Bins of 4 Years 

#year_bins = [0, 9, 14, 19, 24, 29, 34, 39, 50]
#bin_labels = ["<10","10-14", "15-19", "20-24", "25-29", "30-34", "35-39","40+"]

#pymoli_file_df["Age Range"] = pd.cut(pymoli_file_df["Age"], year_bins, labels=bin_labels, include_lowest=True)
#print(pymoli_file_df)
